# %%
import pandas as pd

df = pd.read_csv('./data.csv')
df = df.set_index("id")

print("Shape of DataFrame:", df.shape)
# Out:
# Shape of DataFrame: (1666, 21)

# %%
df.head(10)
# Out:
#                                                  slug  \
# id
# 0   https://www.mega.pk/mobiles_products/23522/Not...
# 1   https://www.mega.pk/mobiles_products/23458/Opp...
# 2   https://www.mega.pk/mobiles_products/24393/Tec...
# 3   https://www.mega.pk/mobiles_products/24259/Viv...
# 4   https://www.mega.pk/mobiles_products/24204/App...
# 5   https://www.mega.pk/mobiles_products/24114/Rea...
# 6   https://www.mega.pk/mobiles_products/24418/Tec...
# 7   https://www.mega.pk/mobiles_products/24417/Spa...
# 8   https://www.mega.pk/mobiles_products/24412/Tec...
# 9   https://www.mega.pk/mobiles_products/24411/Viv...
#
#                                                 title  \
# id
# 0   Nothing Phone 1 8GB RAM 256GB Storage Non PTA ...
# 1   Oppo F21 Pro 8GB Ram 128GB Storage 5G PTA Appr...
# 2                                     Tecno Spark 10
# 3                                        Vivo V27 5G
# 4                            Apple Iphone 15 Pro Max
# 5                                         Realme GT3
# 6         Sparx S9 2GB RAM 32GB Storage PTA Approved
# 7                      Sparx S6 2GB RAM 32GB Storage
# 8   Tecno Pova Neo 2 4GB RAM 64GB Storage PTA Appr...
# 9        Vivo Y73 8GB RAM 128GB Storage PTA Approved
#
#                                                  imgs   brand category  \
# id
# 0   ['https://www.mega.pk/items_images/Nothing+Pho...     NaN   Mobile
# 1   ['https://www.mega.pk/items_images/Oppo+F21+Pr...    OPPO   Mobile
# 2   ['https://www.mega.pk/items_images/Tecno+Spark...   Tecno   Mobile
# 3   ['https://www.mega.pk/items_images/Vivo+V27+5G...    Vivo   Mobile
# 4   ['https://www.mega.pk/items_images/Apple+Iphon...   Apple   Mobile
# 5   ['https://www.mega.pk/items_images/Realme+GT3_...  Realme   Mobile
# 6   ['https://www.mega.pk/items_images/Sparx+S9+2G...   Sparx   Mobile
# 7   ['https://www.mega.pk/items_images/Sparx+S6+2G...   Sparx   Mobile
# 8   ['https://www.mega.pk/items_images/Tecno+Pova+...   Tecno   Mobile
# 9   ['https://www.mega.pk/items_images/Vivo+Y73+8G...    Vivo   Mobile
#
#      vendor  used                                            address  \
# id
# 0   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 1   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 2   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 3   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 4   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 5   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 6   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 7   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 8   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
# 9   MEGA.PK     0  Office 11, 12, 14 Basement Ahmed Center, I-8 M...
#
#    availability currency  ...  discounted_price  \
# id                        ...
# 0           NaN      PKR  ...               NaN
# 1           NaN      PKR  ...               NaN
# 2   Coming Soon      PKR  ...               NaN
# 3   Coming Soon      PKR  ...               NaN
# 4   Coming Soon      PKR  ...               NaN
# 5   Coming Soon      PKR  ...               NaN
# 6           NaN      PKR  ...               NaN
# 7           NaN      PKR  ...               NaN
# 8           NaN      PKR  ...               NaN
# 9           NaN      PKR  ...               NaN
#
#                                        specifications description  \
# id
# 0   {'RAM': '8GB', 'Memory quantity': '', 'Interna...         NaN
# 1   {'RAM': '8gb', 'Memory quantity': '', 'Interna...         NaN
# 2   {'RAM': '4GB,8GB', 'Memory quantity': '', 'Int...         NaN
# 3   {'RAM': '8GB,12GB', 'Memory quantity': '', 'In...         NaN
# 4   {'RAM': '8GB', 'Memory quantity': '', 'Interna...         NaN
# 5   {'RAM': '8GB,12GB,16GB', 'Memory quantity': ''...         NaN
# 6   {'RAM': '2 GB', 'Memory quantity': '', 'Intern...         NaN
# 7   {'RAM': '2 GB', 'Memory quantity': '', 'Intern...         NaN
# 8   {'RAM': '4GB', 'Memory quantity': '', 'Interna...         NaN
# 9   {'RAM': '8 GB', 'Memory quantity': '', 'Intern...         NaN
#
#    delivery_fee  delivery_details  warranty warranty_type average_rating  \
# id
# 0           NaN               NaN       NaN           NaN            NaN
# 1           NaN               NaN       NaN           NaN            NaN
# 2           NaN               NaN    1 year           NaN            NaN
# 3           NaN               NaN    1 year           NaN            NaN
# 4           NaN               NaN       NaN           NaN            NaN
# 5           NaN               NaN    1 year           NaN            NaN
# 6           NaN               NaN    1 year           NaN            NaN
# 7           NaN               NaN    1 year           NaN            NaN
# 8           NaN               NaN    1 year           NaN            NaN
# 9           NaN               NaN    1 year           NaN            NaN
#
#     num_ratings  reviews
# id
# 0           NaN       []
# 1           NaN       []
# 2           NaN       []
# 3           NaN       []
# 4           NaN       []
# 5           NaN       []
# 6           NaN       []
# 7           NaN       []
# 8           NaN       []
# 9           NaN       []
#
# [10 rows x 21 columns]

# %%
df['reviews'] = df['reviews'].fillna(str([])).map(eval)
df['imgs'] = df['imgs'].map(eval)
df['specifications'] = df['specifications'].map(eval)

# %%
def convert_to_sentences(row):
    sep = " __ "
    invalids = {"-", "N/A", "NA", "N\\A"}

    sents = []
    for k, v in row.items():

        if type(v) == list:
            if len(v) == 0: continue
            sent = k + " " + " ".join(v)

        elif type(v) == dict:
            if len(v) == 0: continue
            # sent = sep.join([f"{k2} {v2}" for k2, v2 in v.items() if v2 not in invalids])
            for k2, v2 in v.items():
                if v2 not in invalids:
                    sents.append(f"{k2} {v2}")
            continue

        else:
            if pd.isna(v): continue
            sent = f"{k} {v}"

        sent = sent.lower()
        sent = [i for i in sent.split(". ") if len(i) > 0]
        sents.extend(sent)
    
    sents = ". ".join(sents)
    sents = sents.lower()

    return sents

convert_to_sentences(df.iloc[0])
# Out:
# 'slug https://www.mega.pk/mobiles_products/23522/nothing-phone-1-8gb-ram-256gb-storage-non-pta-5g-black.html. title nothing phone 1 8gb ram 256gb storage non pta 5g black . imgs https://www.mega.pk/items_images/nothing+phone+1+8gb+ram+256gb+storage+non+pta+5g+black+price+in+pakistan%2c+specifications%2c+features_-_23522.webp. category mobile. vendor mega.pk. used 0. address office 11, 12, 14 basement ahmed center, i-8 markaz, islamabad, pakistan. currency pkr. original_price 129999.0. ram 8gb. memory quantity . internal storage space 256gb. main camera pixels 50 mp, f/1.9, 24mm (wide), 1/1.56. battery capacity li-po 4500 mah, non-removable. screen size 6.55 inches. 5g support yes. finger print yes. display technology oled, 1b colors, 120hz, hdr10+, 500 nits (typ), 700 nits (peak). display 6.55 inches oled, 1b colors. number of colours 1b. scratch resistant display . screen resolution 1080 x 2400 pixels. pixel density 402 ppi. dual screens . sd card yes. sdio . compatible memory cards 128gb 8gb ram, 256gb 8gb ram, 256gb 12gb ram. maximum amount of memory . built-in camera yes. auto focus yes. built-in flash yes. digital zoom (still image) yes. maximum resolution (still) 1080p 30fps. number of cameras 3. front camera resolution 16 mp, f/2.5, (wide), 1/3.1. optical zoom yes. video recorder yes. digital zoom (video) yes. maximum numbers of fps when recording 30fps. maximum resolution (video) 4k 30fps. graphics processor yes. graphics processor type . processor core type octa-core. processor speed 1x2.5 ghz cortex-a78 & 3x2.4 ghz cortex-a78. chipset qualcomm sm7325-ae snapdragon 778g+ 5g (6 nm). cpu type octa-core (1x2.5 ghz cortex-a78 & 3x2.4 ghz cortex-a78 & 4x1.9 ghz cortex-a55). 4g lte yes. bluetooth yes. nfc support yes. wifi (wireless fidelity) yes. colour white, black. features (detail) fingerprint (under display, optical), accelerometer, proximity, gyro, compass. shock resistant . dual sim card support yes. voice dialing yes. water resistant . 3.5mm headphone output . type of connection . dimensions (wxhxd) 159.2 x 75.8 x 8.3 mm (6.27 x 2.98 x 0.33 in). weight 193.5 g (6.84 oz). operating system android 12, nothing os 1.1.3. release year 2022. pta approved no. warranty . price 129,999 - pkr\xa0price in pakistani rupees'

# %%
df['sentences'] = df.apply(convert_to_sentences, axis=1)

# %%
ids = df.index
documents = df['sentences']
metadata = df[['title', 'brand', 'category', 'vendor', 'used', 'original_price', 'discounted_price']].fillna("").to_dict(orient='records')

# %%
qdrant_coll_name = "ecommerce-col"

# %%
# !pip install qdrant-client[fastembed]
# Out:
# Requirement already satisfied: qdrant-client[fastembed] in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (1.8.2)
# Requirement already satisfied: httpx[http2]>=0.20.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (0.27.0)
# Requirement already satisfied: numpy>=1.21 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (1.26.4)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (2.2.1)
# Requirement already satisfied: grpcio>=1.41.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (1.62.1)
# Requirement already satisfied: pydantic>=1.10.8 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (2.7.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (1.62.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (2.8.2)
# Requirement already satisfied: fastembed==0.2.5 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from qdrant-client[fastembed]) (0.2.5)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (0.7.2)
# Requirement already satisfied: requests<3.0,>=2.31 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (2.31.0)
# Requirement already satisfied: huggingface-hub<0.21,>=0.20 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (0.20.3)
# Requirement already satisfied: tokenizers<0.16.0,>=0.15.1 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (0.15.2)
# Requirement already satisfied: onnxruntime<2.0.0,>=1.17.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (1.17.3)
# Requirement already satisfied: tqdm<5.0,>=4.66 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (4.66.2)
# Requirement already satisfied: onnx<2.0.0,>=1.15.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from fastembed==0.2.5->qdrant-client[fastembed]) (1.16.0)
# Requirement already satisfied: protobuf<5.0dev,>=4.21.6 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from grpcio-tools>=1.41.0->qdrant-client[fastembed]) (4.25.3)
# Requirement already satisfied: setuptools in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from grpcio-tools>=1.41.0->qdrant-client[fastembed]) (59.6.0)
# Requirement already satisfied: certifi in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant-client[fastembed]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant-client[fastembed]) (1.0.5)
# Requirement already satisfied: anyio in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant-client[fastembed]) (4.3.0)
# Requirement already satisfied: idna in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant-client[fastembed]) (3.7)
# Requirement already satisfied: sniffio in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant-client[fastembed]) (1.3.1)
# Requirement already satisfied: h2<5,>=3 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant-client[fastembed]) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from httpcore==1.*->httpx[http2]>=0.20.0->qdrant-client[fastembed]) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant-client[fastembed]) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant-client[fastembed]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant-client[fastembed]) (2.18.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client[fastembed]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client[fastembed]) (4.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.5->qdrant-client[fastembed]) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.5->qdrant-client[fastembed]) (24.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.5->qdrant-client[fastembed]) (2024.3.1)
# Requirement already satisfied: filelock in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from huggingface-hub<0.21,>=0.20->fastembed==0.2.5->qdrant-client[fastembed]) (3.13.4)
# Requirement already satisfied: flatbuffers in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.5->qdrant-client[fastembed]) (24.3.25)
# Requirement already satisfied: sympy in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.5->qdrant-client[fastembed]) (1.12)
# Requirement already satisfied: coloredlogs in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.5->qdrant-client[fastembed]) (15.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from requests<3.0,>=2.31->fastembed==0.2.5->qdrant-client[fastembed]) (3.3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from anyio->httpx[http2]>=0.20.0->qdrant-client[fastembed]) (1.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.5->qdrant-client[fastembed]) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/syedjafer/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages (from sympy->onnxruntime<2.0.0,>=1.17.0->fastembed==0.2.5->qdrant-client[fastembed]) (1.3.0)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 first_collection = client.recreate_collection(
#       2     collection_name=my_collection,
#       3     vectors_config=models.VectorParams(size=100, distance=models.Distance.COSINE)
#       4 )
#
# NameError: name 'client' is not defined

# %%
client.add(
    collection_name="demo_collection",
    documents=documents,
    metadata=metadata,
    ids=ids
)

# %%
search_result = client.query(
    collection_name="demo_collection",
    query_text="realme"
)
print(search_result)

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models

client = QdrantClient(host="localhost", port=6333)
client.create_collection(qdrant_coll_name, vectors_config={
        "image": models.VectorParams(size=4, distance=models.Distance.DOT),
        "text": models.VectorParams(size=8, distance=models.Distance.COSINE),
    },)
client.add(
    collection_name=qdrant_coll_name,
    ids=ids,
    documents=documents,
    metadata=metadata,
)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 9
#       4 client = QdrantClient(host="localhost", port=6333)
#       5 client.create_collection(qdrant_coll_name, vectors_config={
#       6         "image": models.VectorParams(size=4, distance=models.Distance.DOT),
#       7         "text": models.VectorParams(size=8, distance=models.Distance.COSINE),
#       8     },)
# ----> 9 client.add(
#      10     collection_name=qdrant_coll_name,
#      11     ids=ids,
#      12     documents=documents,
#      13     metadata=metadata,
#      14 )
#
# File ~/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages/qdrant_client/qdrant_fastembed.py:496, in QdrantFastembedMixin.add(self, collection_name, documents, metadata, ids, batch_size, parallel, **kwargs)
#     489     self.create_collection(
#     490         collection_name=collection_name,
#     491         vectors_config=self.get_fastembed_vector_params(),
#     492         sparse_vectors_config=self.get_fastembed_sparse_vector_params(),
#     493     )
#     494     collection_info = self.get_collection(collection_name=collection_name)
# --> 496 self._validate_collection_info(collection_info)
#     498 inserted_ids: list = []
#     500 points = self._points_iterator(
#     501     ids=ids,
#     502     metadata=metadata,
#    (...)
#     505     sparse_vectors=encoded_sparse_docs,
#     506 )
#
# File ~/Documents/Projects/qdrant-tasks/qVenv/lib/python3.10/site-packages/qdrant_client/qdrant_fastembed.py:353, in QdrantFastembedMixin._validate_collection_info(self, collection_info)
#     347 # Check if collection has compatible vector params
#     348 assert isinstance(
#     349     collection_info.config.params.vectors, dict
#     350 ), f"Collection have incompatible vector params: {collection_info.config.params.vectors}"
#     352 assert (
# --> 353     vector_field_name in collection_info.config.params.vectors
#     354 ), f"Collection have incompatible vector params: {collection_info.config.params.vectors}, expected {vector_field_name}"
#     356 vector_params = collection_info.config.params.vectors[vector_field_name]
#     358 assert (
#     359     embeddings_size == vector_params.size
#     360 ), f"Embedding size mismatch: {embeddings_size} != {vector_params.size}"
#
# AssertionError: Collection have incompatible vector params: {'image': VectorParams(size=4, distance=<Distance.DOT: 'Dot'>, hnsw_config=None, quantization_config=None, on_disk=None), 'text': VectorParams(size=8, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None)}, expected fast-bge-small-en

# %%
from fastembed.embedding import DefaultEmbedding
# Out:
# 2024-04-16 10:04:24.036 | WARNING  | fastembed.embedding:<module>:7 - DefaultEmbedding, FlagEmbedding, JinaEmbedding are deprecated.Use from fastembed import TextEmbedding instead.

# %%
documents: list[str] = [
    "passage: Hello, World!",
    "query: How is the World?",
    "passage: This is an example passage.",
    "fastembed is supported by and maintained by Qdrant."
]

# %%
embedding_model = DefaultEmbedding()
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
import numpy as np

# %%
embeddings: list[np.ndarray] = list(embedding_model.embed(documents))

# %%
from qdrant_client import QdrantClient
# Initialize the client
client = QdrantClient(":memory:")  # or QdrantClient(path="path/to/db")

# %%
docs = [
    "Qdrant has Langchain integrations",
    "Qdrant also has Llama Index integrations"
]
metadata = [
    {"source": "Langchain-docs"},
    {"source": "LlamaIndex-docs"},
]
ids = [42, 2]

# %%
client.add(
    collection_name="demo_collection",
    documents=docs,
    metadata=metadata,
    ids=ids
)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 77.7M/77.7M [00:13<00:00, 5.86MiB/s]
# [42, 2]

# %%
search_result = client.query(
    collection_name="demo_collection",
    query_text="This is a query document"
)
print(search_result)
# Out:
# [QueryResponse(id=42, embedding=None, sparse_embedding=None, metadata={'document': 'Qdrant has Langchain integrations', 'source': 'Langchain-docs'}, document='Qdrant has Langchain integrations', score=0.813332812591849), QueryResponse(id=2, embedding=None, sparse_embedding=None, metadata={'document': 'Qdrant also has Llama Index integrations', 'source': 'LlamaIndex-docs'}, document='Qdrant also has Llama Index integrations', score=0.8104903275080046)]
